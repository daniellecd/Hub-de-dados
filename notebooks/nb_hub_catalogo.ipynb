# %%
# %%configure -f
# {
#     "defaultLakehouse": {
#         "name": "lh_hub"
#     }
# }

# %% [markdown]
# # Sincronização do catálogo
#
# Atualiza a parte estrutural do catálogo a partir dos contratos, preserva a curadoria e aplica os comentários físicos.
#
# Parâmetros:
#
# - `ambiente`: dev, hml ou prod.
#
# Gerado por `ferramentas/gerar_notebooks.py`. Não edite no Fabric: altere o repositório, gere novamente e reimporte.

# %%
ambiente = 'dev'

# %%
# %run nb_hub_biblioteca

# %%
resultado = hub.orquestracao.sincronizar_catalogo(
    spark,
    REGISTRO,
    ambiente=ambiente,
)
resultado
