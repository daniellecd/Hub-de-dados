# %%
# %%configure -f
# {
#     "defaultLakehouse": {
#         "name": "lh_hub"
#     }
# }

# %% [markdown]
# # Diagnóstico de referências
#
# Diagnóstico dirigido, fora do fluxo obrigatório: confere os domínios por referência da entidade contra as tabelas oficiais. Não bloqueia a entidade de negócio.
#
# Parâmetros:
#
# - `ambiente`: dev, hml ou prod.
# - `entidade`: identificador fonte_base_entidade.
#
# Gerado por `ferramentas/gerar_notebooks.py`. Não edite no Fabric: altere o repositório, gere novamente e reimporte.

# %%
ambiente = 'dev'
entidade = 'rfb_cno_obras'

# %%
# %run nb_hub_biblioteca

# %%
import json

resultado = hub.orquestracao.diagnosticar_referencias(
    spark,
    REGISTRO,
    ambiente=ambiente,
    entidade=entidade,
)
print(json.dumps(resultado, ensure_ascii=False, indent=2))
