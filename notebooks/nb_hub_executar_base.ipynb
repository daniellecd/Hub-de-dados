# %%
# %%configure -f
# {
#     "defaultLakehouse": {
#         "name": "lh_hub"
#     }
# }

# %% [markdown]
# # Execução da base
#
# Aquisição, Bronze e Silver de todas as entidades da base, em sequência. Entidades são independentes; falhas são reportadas ao final.
#
# Parâmetros:
#
# - `ambiente`: dev, hml ou prod.
# - `fonte`: fonte da base.
# - `base`: base da fonte.
# - `competencia`: competência AAAA-MM.
# - `forcar_aquisicao`: True para adquirir de novo a competência.
#
# Gerado por `ferramentas/gerar_notebooks.py`. Não edite no Fabric: altere o repositório, gere novamente e reimporte.

# %%
ambiente = 'dev'
fonte = 'rfb'
base = 'cno'
competencia = '2026-09'
forcar_aquisicao = False

# %%
# %run nb_hub_biblioteca

# %%
resultado = hub.orquestracao.executar_base(
    spark,
    REGISTRO,
    ambiente=ambiente,
    fonte=fonte,
    base=base,
    competencia=competencia,
    forcar_aquisicao=forcar_aquisicao,
)
resultado
