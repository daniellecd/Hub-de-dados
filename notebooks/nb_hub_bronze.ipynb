# %%
# %%configure -f
# {
#     "defaultLakehouse": {
#         "name": "lh_hub"
#     }
# }

# %% [markdown]
# # Publicação Bronze
#
# Lê a aquisição efetiva conforme o contrato, mantém tudo como texto, envia linhas malformadas à quarentena, reconcilia e publica o snapshot.
#
# Parâmetros:
#
# - `ambiente`: dev, hml ou prod.
# - `entidade`: identificador fonte_base_entidade.
# - `competencia`: competência AAAA-MM.
# - `permitir_competencia_anterior`: True apenas para reverter o snapshot a uma competência anterior.
#
# Gerado por `ferramentas/gerar_notebooks.py`. Não edite no Fabric: altere o repositório, gere novamente e reimporte.

# %%
ambiente = 'dev'
entidade = 'rfb_cno_obras'
competencia = '2026-09'
permitir_competencia_anterior = False

# %%
# %run nb_hub_biblioteca

# %%
resultado = hub.orquestracao.publicar_bronze(
    spark,
    REGISTRO,
    ambiente=ambiente,
    entidade=entidade,
    competencia=competencia,
    permitir_competencia_anterior=permitir_competencia_anterior,
)
resultado
